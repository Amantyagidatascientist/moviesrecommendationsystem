# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import time

# %% [markdown]
#  # Load the Data

# %%
data=pd.read_csv("E:/movies_recommendation_system/artifacts/raw.csv")

# %%
data.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148      0  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169      0  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152      0  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162      0  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143      0  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
data.tail()
# Out:
#               id                                title  vote_average  \
# 1068592   713630                               Drifts           0.0
# 1068593   713631  ANIMAL CONDENSED>>ANIMAL EXPANDED#2           0.0
# 1068594   713634         Southern Journey (Revisited)           0.0
# 1068595   713635                La Dame de chez Maxim           0.0
# 1068596  1321103                             Black Ag           0.0
#
#          vote_count    status release_date  revenue  runtime  adult  \
# 1068592           0  Released   2017-01-01        0        8      0
# 1068593           0  Released   2018-06-04        0       14      0
# 1068594           0  Released   2020-06-20        0        0      0
# 1068595           0  Released   2020-06-07        0      125      0
# 1068596           0  Released          NaN        0        9      0
#
#         backdrop_path  ...                       original_title  \
# 1068592           NaN  ...                               Drifts
# 1068593           NaN  ...  ANIMAL CONDENSED>>ANIMAL EXPANDED#2
# 1068594           NaN  ...         Southern Journey (Revisited)
# 1068595           NaN  ...                La Dame de chez Maxim
# 1068596           NaN  ...                             Black Ag
#
#                                                   overview popularity  \
# 1068592                                   Milling about...      0.600
# 1068593  The director couldn’t have anticipated the cor...      0.600
# 1068594  Traversing the back-roads of the Southern Unit...      0.600
# 1068595  Doctor Petypon, a respectable doctor, partied ...      0.681
# 1068596  A Black scientist brings together local Black ...      0.600
#
#                               poster_path tagline              genres  \
# 1068592  /p8TSAA4hz7yJPgOC38EcQsE1OqV.jpg     NaN         Documentary
# 1068593  /7tLfGkmRZeepntPuyIq8ywLLlS2.jpg     NaN     Science Fiction
# 1068594  /aJZoxfiJ1cq9KIL41UCDbXrwXO7.jpg     NaN  Documentary, Music
# 1068595  /gX66xwbdFlMkif1c4rkIAEDBxuD.jpg     NaN              Comedy
# 1068596                               NaN     NaN                 NaN
#
#                                       production_companies  \
# 1068592                                                NaN
# 1068593  Arts Council England, University of the Arts L...
# 1068594                                                NaN
# 1068595  le Théâtre de Montansier de Versailles, Theatr...
# 1068596                                                NaN
#
#         production_countries spoken_languages      keywords
# 1068592                  NaN          English           NaN
# 1068593       United Kingdom          English           NaN
# 1068594                  NaN              NaN           NaN
# 1068595               France           French  theater play
# 1068596                  NaN              NaN           NaN
#
# [5 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068597 entries, 0 to 1068596
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1068597 non-null  int64
#  1   title                 1068585 non-null  object
#  2   vote_average          1068597 non-null  float64
#  3   vote_count            1068597 non-null  int64
#  4   status                1068597 non-null  object
#  5   release_date          919961 non-null   object
#  6   revenue               1068597 non-null  int64
#  7   runtime               1068597 non-null  int64
#  8   adult                 1068597 non-null  int64
#  9   backdrop_path         292281 non-null   object
#  10  budget                1068597 non-null  int64
#  11  homepage              115143 non-null   object
#  12  imdb_id               588307 non-null   object
#  13  original_language     1068597 non-null  object
#  14  original_title        1068585 non-null  object
#  15  overview              867546 non-null   object
#  16  popularity            1068597 non-null  float64
#  17  poster_path           752760 non-null   object
#  18  tagline               152245 non-null   object
#  19  genres                658265 non-null   object
#  20  production_companies  495484 non-null   object
#  21  production_countries  614849 non-null   object
#  22  spoken_languages      630610 non-null   object
#  23  keywords              299609 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 195.7+ MB

# %%
data.describe()
# Out:
#                  id  vote_average    vote_count       revenue       runtime  \
# count  1.068597e+06  1.068597e+06  1.068597e+06  1.068597e+06  1.068597e+06
# mean   7.013812e+05  1.985565e+00  2.007031e+01  7.113737e+05  4.924788e+01
# std    3.753771e+05  3.066278e+00  3.284578e+02  1.794087e+07  6.206482e+01
# min    2.000000e+00  0.000000e+00  0.000000e+00 -1.200000e+01 -2.800000e+01
# 25%    3.905210e+05  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    7.038130e+05  0.000000e+00  0.000000e+00  0.000000e+00  2.600000e+01
# 75%    1.030912e+06  5.000000e+00  1.000000e+00  0.000000e+00  9.000000e+01
# max    1.321371e+06  1.000000e+01  3.449500e+04  3.000000e+09  1.440000e+04
#
#               adult        budget    popularity
# count  1.068597e+06  1.068597e+06  1.068597e+06
# mean   9.306502e-02  2.793325e+05  1.285156e+00
# std    2.905237e-01  5.063786e+06  7.821327e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  6.000000e-01
# 50%    0.000000e+00  0.000000e+00  6.000000e-01
# 75%    0.000000e+00  0.000000e+00  8.850000e-01
# max    1.000000e+00  9.000000e+08  2.994357e+03

# %%
data.describe(include='object')
# Out:
#           title    status release_date                     backdrop_path  \
# count   1068585   1068597       919961                            292281
# unique   918384         6        42494                            289833
# top        Home  Released   2006-01-01  /3CxwYgqGtJ6UEGfWUT0gMYCIlFP.jpg
# freq        144   1047373         3529                               157
#
#                               homepage     imdb_id original_language  \
# count                           115143      588307           1068597
# unique                          108249      587569               174
# top     https://animation.geidai.ac.jp  tt32094375                en
# freq                               147          35            579071
#
#        original_title overview                       poster_path  tagline  \
# count         1068585   867546                            752760   152245
# unique         951334   844306                            748532   146601
# top          Untitled           /wtoKLMm4UvkwvcSwO3XWcs1gJuF.jpg  English
# freq              101      997                                54      195
#
#              genres production_companies      production_countries  \
# count        658265               495484                    614849
# unique        13009               199658                      9925
# top     Documentary           Evil Angel  United States of America
# freq         129712                 2866                    172566
#
#        spoken_languages    keywords
# count            630610      299609
# unique             6975      171888
# top             English  short film
# freq             224694       10258

# %%
data.duplicated().sum()
# Out:
# 365

# %%
data.isnull().sum()
# Out:
# id                           0
# title                       12
# vote_average                 0
# vote_count                   0
# status                       0
# release_date            148636
# revenue                      0
# runtime                      0
# adult                        0
# backdrop_path           776316
# budget                       0
# homepage                953454
# imdb_id                 480290
# original_language            0
# original_title              12
# overview                201051
# popularity                   0
# poster_path             315837
# tagline                 916352
# genres                  410332
# production_companies    573113
# production_countries    453748
# spoken_languages        437987
# keywords                768988
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# Row 12 has null data in the title column. Some columns also have null or zero values. We should drop rows with null values and decide if columns with zero values should be removed.

# %%
data['title'].isnull().sum()
# Out:
# 12

# %%
data=data[~data['title'].isnull()]

# %%
data.isnull().sum()
# Out:
# id                           0
# title                        0
# vote_average                 0
# vote_count                   0
# status                       0
# release_date            148414
# revenue                      0
# runtime                      0
# adult                        0
# backdrop_path           775972
# budget                       0
# homepage                953113
# imdb_id                 480019
# original_language            0
# original_title               0
# overview                200933
# popularity                   0
# poster_path             315603
# tagline                 916018
# genres                  410064
# production_companies    572834
# production_countries    453458
# spoken_languages        437707
# keywords                768694
# dtype: int64

# %%
data['release_date']=pd.to_datetime(data['release_date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1068220 entries, 0 to 1068596
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1068220 non-null  int64
#  1   title                 1068220 non-null  object
#  2   vote_average          1068220 non-null  float64
#  3   vote_count            1068220 non-null  int64
#  4   status                1068220 non-null  object
#  5   release_date          919806 non-null   datetime64[ns]
#  6   revenue               1068220 non-null  int64
#  7   runtime               1068220 non-null  int64
#  8   adult                 1068220 non-null  int64
#  9   backdrop_path         292248 non-null   object
#  10  budget                1068220 non-null  int64
#  11  homepage              115107 non-null   object
#  12  imdb_id               588201 non-null   object
#  13  original_language     1068220 non-null  object
#  14  original_title        1068220 non-null  object
#  15  overview              867287 non-null   object
#  16  popularity            1068220 non-null  float64
#  17  poster_path           752617 non-null   object
#  18  tagline               152202 non-null   object
#  19  genres                658156 non-null   object
#  20  production_companies  495386 non-null   object
#  21  production_countries  614762 non-null   object
#  22  spoken_languages      630513 non-null   object
#  23  keywords              299526 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(6), object(15)
# memory usage: 203.7+ MB

# %% [markdown]
# We use  default date makes sense in your context.

# %%
default=pd.Timestamp('2000-01-01')

# %%
data['release_date']=data['release_date'].fillna(default)

# %%
data.isnull().sum()
# Out:
# id                           0
# title                        0
# vote_average                 0
# vote_count                   0
# status                       0
# release_date                 0
# revenue                      0
# runtime                      0
# adult                        0
# backdrop_path           775972
# budget                       0
# homepage                953113
# imdb_id                 480019
# original_language            0
# original_title               0
# overview                200933
# popularity                   0
# poster_path             315603
# tagline                 916018
# genres                  410064
# production_companies    572834
# production_countries    453458
# spoken_languages        437707
# keywords                768694
# dtype: int64

# %%
data.shape
# Out:
# (1068220, 24)

# %% [markdown]
# he runtime column shows zero values and revenue is also zero. Other columns have null values. We should drop columns with these issues

# %%
data[(data.runtime==0)& (data.spoken_languages.isnull())]
# Out:
#              id                             title  vote_average  vote_count  \
# 6011     320367                            Return         6.223         551
# 11787    270479         Ammutta muddica al cinema         6.500         199
# 13835    546266              La fuitina sbagliata         6.400         155
# 15978    379979   ASD - Alma sin dueño (Sin alma)         5.980         123
# 16184     82812       SMS - Sotto mentite spoglie         4.896         120
# ...         ...                               ...           ...         ...
# 1068545  713568            Obituary Love Morphine         0.000           0
# 1068548  713573                Beneath Her Shroud         0.000           0
# 1068581  713617                              百变神偷         0.000           0
# 1068582  713618  Nous sommes tous juifs allemands         0.000           0
# 1068594  713634      Southern Journey (Revisited)         0.000           0
#
#            status release_date  revenue  runtime  adult  \
# 6011     Released   2015-01-01        0        0      0
# 11787    Released   2013-10-16        0        0      0
# 13835    Released   2018-10-11        0        0      0
# 15978    Released   2010-01-29        0        0      0
# 16184    Released   2007-01-01        0        0      0
# ...           ...          ...      ...      ...    ...
# 1068545  Released   2022-04-11        0        0      0
# 1068548  Released   2022-03-08        0        0      0
# 1068581  Released   1989-01-01        0        0      0
# 1068582  Released   2020-06-07        0        0      0
# 1068594  Released   2020-06-20        0        0      0
#
#                             backdrop_path  ...  \
# 6011                                  NaN  ...
# 11787    /hJJn2jntZYAdD4vyUk4GkMPMeEA.jpg  ...
# 13835    /pWvfCPqcR1NGUbgEqkXYKXRfL6h.jpg  ...
# 15978                                 NaN  ...
# 16184    /nTa110xRiMPGfrpdgNy6IEZjg27.jpg  ...
# ...                                   ...  ...
# 1068545                               NaN  ...
# 1068548                               NaN  ...
# 1068581  /qFZEiLSwqesVpUaHxpUSTUjArVP.jpg  ...
# 1068582  /vj1XqhPv9JU6bRAX0Be3tYzpteP.jpg  ...
# 1068594                               NaN  ...
#
#                            original_title  \
# 6011                               Return
# 11787           Ammutta muddica al cinema
# 13835                La fuitina sbagliata
# 15978     ASD - Alma sin dueño (Sin alma)
# 16184         SMS - Sotto mentite spoglie
# ...                                   ...
# 1068545            Obituary Love Morphine
# 1068548                Beneath Her Shroud
# 1068581                              百变神偷
# 1068582  Nous sommes tous juifs allemands
# 1068594      Southern Journey (Revisited)
#
#                                                   overview popularity  \
# 6011     A tale of terror. Cathy Reed has been institut...      4.037
# 11787                                                  NaN      4.414
# 13835                                                  NaN      3.947
# 15978                                                  NaN      3.852
# 16184                                                  NaN      6.684
# ...                                                    ...        ...
# 1068545  A man and a woman exploring their organic life...      0.886
# 1068548  After the nocturnal collision, an 80-year-old ...      1.138
# 1068581                                                NaN      0.600
# 1068582                                                NaN      0.600
# 1068594  Traversing the back-roads of the Southern Unit...      0.600
#
#                               poster_path                        tagline  \
# 6011                                  NaN                            NaN
# 11787    /mhNyJcDEud5IQBYyk05V6o70sjX.jpg                            NaN
# 13835    /u4voK60V7mR59E2Y81DbIfJFlUZ.jpg                            NaN
# 15978                                 NaN                            NaN
# 16184    /oHOIddLuQFz6aHfARxkKxasZeHB.jpg                            NaN
# ...                                   ...                            ...
# 1068545                               NaN                            NaN
# 1068548                               NaN  Imagine a world without woman
# 1068581  /iawjLEFdj8SoHeQOCrHkncj8gCk.jpg                            NaN
# 1068582  /iazIgODucRAzaSkvdeACRC3qNXt.jpg                            NaN
# 1068594  /aJZoxfiJ1cq9KIL41UCDbXrwXO7.jpg                            NaN
#
#                      genres  production_companies production_countries  \
# 6011                    NaN                   NaN                  NaN
# 11787                Comedy                   NaN                Italy
# 13835                Comedy                   NaN                  NaN
# 15978              Thriller        Alma Ata Films                Spain
# 16184                Comedy                   NaN                Italy
# ...                     ...                   ...                  ...
# 1068545      Mystery, Drama      Zero Degree Arts                India
# 1068548      Mystery, Drama      Zero Degree Arts                  NaN
# 1068581                 NaN                   NaN                  NaN
# 1068582         Documentary                   NaN               France
# 1068594  Documentary, Music                   NaN                  NaN
#
#         spoken_languages                                           keywords
# 6011                 NaN                                                NaN
# 11787                NaN                                                NaN
# 13835                NaN                                                NaN
# 15978                NaN                                            monster
# 16184                NaN                                                NaN
# ...                  ...                                                ...
# 1068545              NaN  schizophrenia, sibling relationship, love, nar...
# 1068548              NaN  rape, murder, misogyny, chauvinisim, female fo...
# 1068581              NaN                                                NaN
# 1068582              NaN                                                NaN
# 1068594              NaN                                                NaN
#
# [165611 rows x 24 columns]

# %%
data=data[~((data.runtime==0)& (data.spoken_languages.isnull()))]

# %% [markdown]
# We dropped some columns: backdrop_path, homepage, poster_path, and imdb_id. I did not find these columns required for EDA and training the machine learning model

# %%
data
# Out:
#               id                                title  vote_average  \
# 0          27205                            Inception         8.364
# 1         157336                         Interstellar         8.417
# 2            155                      The Dark Knight         8.512
# 3          19995                               Avatar         7.573
# 4          24428                         The Avengers         7.710
# ...          ...                                  ...           ...
# 1068591   713629           The Psychosis of Whiteness         0.000
# 1068592   713630                               Drifts         0.000
# 1068593   713631  ANIMAL CONDENSED>>ANIMAL EXPANDED#2         0.000
# 1068595   713635                La Dame de chez Maxim         0.000
# 1068596  1321103                             Black Ag         0.000
#
#          vote_count    status release_date     revenue  runtime  adult  \
# 0             34495  Released   2010-07-15   825532764      148      0
# 1             32571  Released   2014-11-05   701729206      169      0
# 2             30619  Released   2008-07-16  1004558444      152      0
# 3             29815  Released   2009-12-15  2923706026      162      0
# 4             29166  Released   2012-04-25  1518815515      143      0
# ...             ...       ...          ...         ...      ...    ...
# 1068591           0  Released   2018-04-04           0       85      0
# 1068592           0  Released   2017-01-01           0        8      0
# 1068593           0  Released   2018-06-04           0       14      0
# 1068595           0  Released   2020-06-07           0      125      0
# 1068596           0  Released   2000-01-01           0        9      0
#
#                             backdrop_path  ...  \
# 0        /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1        /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2        /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3        /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4        /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
# ...                                   ...  ...
# 1068591                               NaN  ...
# 1068592                               NaN  ...
# 1068593                               NaN  ...
# 1068595                               NaN  ...
# 1068596                               NaN  ...
#
#                               original_title  \
# 0                                  Inception
# 1                               Interstellar
# 2                            The Dark Knight
# 3                                     Avatar
# 4                               The Avengers
# ...                                      ...
# 1068591           The Psychosis of Whiteness
# 1068592                               Drifts
# 1068593  ANIMAL CONDENSED>>ANIMAL EXPANDED#2
# 1068595                La Dame de chez Maxim
# 1068596                             Black Ag
#
#                                                   overview popularity  \
# 0        Cobb, a skilled thief who commits corporate es...     83.952
# 1        The adventures of a group of explorers who mak...    140.241
# 2        Batman raises the stakes in his war on crime. ...    130.643
# 3        In the 22nd century, a paraplegic Marine is di...     79.932
# 4        When an unexpected enemy emerges and threatens...     98.082
# ...                                                    ...        ...
# 1068591  The Psychosis of Whiteness sheds light on soci...      0.600
# 1068592                                   Milling about...      0.600
# 1068593  The director couldn’t have anticipated the cor...      0.600
# 1068595  Doctor Petypon, a respectable doctor, partied ...      0.681
# 1068596  A Black scientist brings together local Black ...      0.600
#
#                               poster_path  \
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4         /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                   ...
# 1068591  /12PFVO7VH3UrQ9Qi3bvTefN74ll.jpg
# 1068592  /p8TSAA4hz7yJPgOC38EcQsE1OqV.jpg
# 1068593  /7tLfGkmRZeepntPuyIq8ywLLlS2.jpg
# 1068595  /gX66xwbdFlMkif1c4rkIAEDBxuD.jpg
# 1068596                               NaN
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1068591                                                NaN
# 1068592                                                NaN
# 1068593                                                NaN
# 1068595                                                NaN
# 1068596                                                NaN
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1068591                                          NaN
# 1068592                                  Documentary
# 1068593                              Science Fiction
# 1068595                                       Comedy
# 1068596                                          NaN
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1068591                                                NaN
# 1068592                                                NaN
# 1068593  Arts Council England, University of the Arts L...
# 1068595  le Théâtre de Montansier de Versailles, Theatr...
# 1068596                                                NaN
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1068591                                       NaN
# 1068592                                       NaN
# 1068593                            United Kingdom
# 1068595                                    France
# 1068596                                       NaN
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1068591                                 NaN
# 1068592                             English
# 1068593                             English
# 1068595                              French
# 1068596                                 NaN
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1068591                                                NaN
# 1068592                                                NaN
# 1068593                                                NaN
# 1068595                                       theater play
# 1068596                                                NaN
#
# [902609 rows x 24 columns]

# %%
columns_name=['backdrop_path','homepage','poster_path','imdb_id','tagline','keywords']

# %%
# Drop specific columns from DataFrame
data.drop(columns=columns_name, inplace=True)

# %%
data.isnull().sum()
# Out:
# id                           0
# title                        0
# vote_average                 0
# vote_count                   0
# status                       0
# release_date                 0
# revenue                      0
# runtime                      0
# adult                        0
# budget                       0
# original_language            0
# original_title               0
# overview                102489
# popularity                   0
# genres                  292369
# production_companies    436634
# production_countries    321870
# spoken_languages        272096
# dtype: int64

# %% [markdown]
# Fill the null values in 'spoken_languages' column with values from 'original_language' column

# %%
data['spoken_languages'].fillna(data['original_language'], inplace=True)
# Out:
# C:\Users\tyagi\AppData\Local\Temp\ipykernel_2204\3960036064.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['spoken_languages'].fillna(data['original_language'], inplace=True)

# %% [markdown]
# Fill null values in 'production_companies' with a specific value, e.g., 'Unknown'
# Fill null values in 'production_countries' with a specific value, e.g., 'Unknown'

# %%
data['production_companies'].fillna('Unknown', inplace=True)
data['production_countries'].fillna('Unknown', inplace=True)
data['genres'].fillna('Unknown_genres', inplace=True)
data['overview'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\tyagi\AppData\Local\Temp\ipykernel_2204\2787915242.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['production_companies'].fillna('Unknown', inplace=True)
# C:\Users\tyagi\AppData\Local\Temp\ipykernel_2204\2787915242.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['production_countries'].fillna('Unknown', inplace=True)
# C:\Users\tyagi\AppData\Local\Temp\ipykernel_2204\2787915242.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['genres'].fillna('Unknown_genres', inplace=True)
# C:\Users\tyagi\AppData\Local\Temp\ipykernel_2204\2787915242.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['overview'].fillna('Unknown', inplace=True)

# %%
data.isnull().sum()
# Out:
# id                      0
# title                   0
# vote_average            0
# vote_count              0
# status                  0
# release_date            0
# revenue                 0
# runtime                 0
# adult                   0
# budget                  0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# genres                  0
# production_companies    0
# production_countries    0
# spoken_languages        0
# dtype: int64

# %%
data['production_countries']=data['production_countries'].str.split(',')
data['genres']=data['genres'].str.split(',')
data['production_companies']=data['production_companies'].str.split(',')
data['spoken_languages']=data['spoken_languages'].str.split(',')

# %% [markdown]
# ~We check the M

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots(figsize=(8, 4))
sns.countplot(x=data['status'],ax=ax)
ax.set_title('Movies_status')
ax.set_ylabel('number_of_movies')
ax.bar_label(ax.containers[0], label_type='edge',fontsize=10)
plt.show()

# %% [markdown]
# To understand how your data is spread out or distributed

# %%
from importlib.metadata import distribution


see the data distribution
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult     budget original_language   original_title  \
# 0   825532764      148      0  160000000                en        Inception
# 1   701729206      169      0  165000000                en     Interstellar
# 2  1004558444      152      0  185000000                en  The Dark Knight
# 3  2923706026      162      0  237000000                en           Avatar
# 4  1518815515      143      0  220000000                en     The Avengers
#
#                                             overview  popularity  \
# 0  Cobb, a skilled thief who commits corporate es...      83.952
# 1  The adventures of a group of explorers who mak...     140.241
# 2  Batman raises the stakes in his war on crime. ...     130.643
# 3  In the 22nd century, a paraplegic Marine is di...      79.932
# 4  When an unexpected enemy emerges and threatens...      98.082
#
#                                              genres  \
# 0            [Action,  Science Fiction,  Adventure]
# 1             [Adventure,  Drama,  Science Fiction]
# 2               [Drama,  Action,  Crime,  Thriller]
# 3  [Action,  Adventure,  Fantasy,  Science Fiction]
# 4            [Science Fiction,  Action,  Adventure]
#
#                                 production_companies  \
# 0  [Legendary Pictures,  Syncopy,  Warner Bros. P...
# 1  [Legendary Pictures,  Syncopy,  Lynda Obst Pro...
# 2  [DC Comics,  Legendary Pictures,  Syncopy,  Is...
# 3  [Dune Entertainment,  Lightstorm Entertainment...
# 4                                   [Marvel Studios]
#
#                           production_countries  \
# 0  [United Kingdom,  United States of America]
# 1  [United Kingdom,  United States of America]
# 2  [United Kingdom,  United States of America]
# 3  [United States of America,  United Kingdom]
# 4                   [United States of America]
#
#                           spoken_languages
# 0  [English,  French,  Japanese,  Swahili]
# 1                                [English]
# 2                     [English,  Mandarin]
# 3                      [English,  Spanish]
# 4              [English,  Hindi,  Russian]

# %%
data['spoken_languages']
# Out:
# 0          [English,  French,  Japanese,  Swahili]
# 1                                        [English]
# 2                             [English,  Mandarin]
# 3                              [English,  Spanish]
# 4                      [English,  Hindi,  Russian]
#                             ...
# 1068591                                       [en]
# 1068592                                  [English]
# 1068593                                  [English]
# 1068595                                   [French]
# 1068596                                       [en]
# Name: spoken_languages, Length: 902609, dtype: object
